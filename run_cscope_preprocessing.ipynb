# %%
#from cscope_analysis.crop import cScopeCropGUI
print("imports...")

from pathlib import Path
from cscope_analysis import cScopeRecording

import cv2
import scipy
import caiman as cm
import numpy as np
import matplotlib.pyplot as plt
import h5py
import datajoint as dj
# Out:
# imports...

# %%
dj.conn()
# Out:
# [2022-11-03 12:40:52,407][INFO]: Connecting roaffan@buaws-aws-cf-rds-mysql-prod.cenrervr4svx.us-east-2.rds.amazonaws.com:3306
# [2022-11-03 12:40:52,825][INFO]: Connected roaffan@buaws-aws-cf-rds-mysql-prod.cenrervr4svx.us-east-2.rds.amazonaws.com:3306
# DataJoint connection (connected) roaffan@buaws-aws-cf-rds-mysql-prod.cenrervr4svx.us-east-2.rds.amazonaws.com:3306

# %%
print("setup directories...")

subject = "Rhubarb"
date = "2021_12_16"
index = -1

mini_dir = Path(f"~/eng_research_scottlab/MINISCOPE_DATA/{subject}/{date}").expanduser()
mini_dir = [d for d in mini_dir.iterdir()][index]

cscope_dir = Path(
    f"~/eng_research_scottlab/Users/roaffan/cScope/{subject}/{date}/{mini_dir.stem}"
).expanduser()

print("\nCSCOPE ANALYSIS")
print(f"mini dir = {mini_dir.as_posix()}")
print(f"cscope dir = {cscope_dir.as_posix()}")

crec = cScopeRecording(mini_dir, cscope_dir)

# %%
#vid = cScopeRecording(mini_dir='C:/Users/sujin/cscope_gk/2021_12_14/13_18_58', cscope_dir=None)
#ddir = 'C:/Users/sujin/cscope_gk/2021_12_14/13_18_58'
ddir = 'C:/Users/roaffan/cscope_gk/2021_12_16/12_10_56'
vid  = cScopeRecording(mini_dir=ddir, cscope_dir=None)

# %%
# movie_file=ddir+'/cscope-analysis/green_mc.mp4'
# gm = cm.load(movie_file)
# # gm[np.where(gm<1)] = np.min(gm[gm>0])
# gm[np.where(gm<1)] = np.mean(gm[gm>0])
# plt.imshow(gm[5,:,:])
# plt.show()
# plt.imshow(gm[30000,:,:])
# plt.show()
# print(np.shape(gm))
# print("values of edge pixels in frame 30000:", gm[30000,0:1,0:46] )
# # plt.imshow(gm[90000,:,:])
# # plt.show()

# check data after split
movie_file=ddir+'/cscope-analysis/green.mp4'
cap = cv2.VideoCapture(movie_file)
ret, frame = cap.read()    
print(np.shape(frame))
plt.imshow(frame[:,:,2]) 
plt.show()

# check data after split
movie_file=ddir+'/cscope-analysis/green_mc.mp4'
cap = cv2.VideoCapture(movie_file)
ret, frame = cap.read()    
print(np.shape(frame))
plt.imshow(frame[:,:,2]) 
plt.show()

# # green = h5py.File(open(ddir+'/cscope-analysis/green_mc.h5', "rb"), mode="r")
# # for i in np.arange(0,100):
# #     print( "\n", np.count_nonzero(green["data"][:,:,i]==0) )
# # green.close()
# Out:
# (94, 46, 3)
# (94, 46, 3)

# %%
#  vid.correct_timestamps(save=True, plot=False, overwrite=True)
# vid.split_videos(downsample=8,fps=30,crf=0,crop=None,overwrite=True,progress=True)
# vid.interpolate_green(overwrite=True)
# vid.motion_correction(use_blue=True, parallel=True, processes=None, splits=14, overwrite=True)
vid.hemodynamic_correction(
        max_alpha=9000,
        splits=0,
        n_processes=1,
        use_mc=False,
        progress=False,
        overwrite_hc=True,
        overwrite_h5=True,
        save_hc=True,
        save_h5=True
    )
# Out:
# Saving videos as h5 files...
# green:
# blue:
# Hemodynamic correction...
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []
#
# green caused inf: []

# %%
# #### check data after motion correct
# movie_file= ddir+'/cscope-analysis/blue_mc.mp4'
# cap = cv2.VideoCapture(movie_file)
# ret, frame = cap.read()    
# print(np.shape(frame))
# plt.imshow(frame[:,:,2]) 

# ### check mc h5 files
# filename = ddir+'/cscope-analysis/blue_mc.h5'
# hf = h5py.File(filename, 'r')
# hf.keys()
# print(np.shape(np.array(hf.get('data'))))
# print( np.array(hf.get('data')) )
# print(np.mean(np.array(hf.get('data')),))
# print(np.max(np.array(hf.get('data'))))
# print(np.min(np.array(hf.get('data'))))
# hf.close()

### check dff h5 files
filename = ddir+'/cscope-analysis/dff.h5'
hf = h5py.File(filename, 'r')
hf.keys()
print(np.shape(np.array(hf.get('dff'))))
print(np.mean(np.array(hf.get('dff')),))
print(np.max(np.array(hf.get('dff'))))
print(np.min(np.array(hf.get('dff'))))
dff = np.array(hf.get('dff'))
hf.close()

# ### plot to check hemodynamic corrected df/f frames
# print(np.shape(dff))
# plt.imshow(dff[:,:,5])
# plt.show()

# print(np.shape(dff))
# plt.imshow(dff[:,:,30000])
# plt.show()

# print(np.shape(dff))
# plt.imshow(dff[:,:,50000])
# plt.show()

# %%
plt.plot(np.mean(dff,axis=(0,1))[0:-1])
plt.show()

### plot to check hemodynamic corrected df/f frames
print(np.shape(dff))
plt.imshow(dff[:,:,500])
plt.show()

print(np.shape(dff))
plt.imshow(dff[:,:,550])
plt.show()

print(np.shape(dff))
plt.imshow(dff[:,:,600])
plt.show()

# %%
### save as mat file
savedir=ddir+'/cscope-analysis/'
savefile=savedir+'dff_hemo.mat'
scipy.io.savemat(savefile, {'dff':dff})

# %%
# # check data after hemodynamic correct
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt
# movie_file='C:/Users/sujin/cscope_gk/2021_12_14/13_18_58/cscope-analysis/blue_mc.mp4'
# cap = cv2.VideoCapture(movie_file)
# ret, frame = cap.read()    
# print(np.shape(frame))
# plt.imshow(frame[:,:,2])
